# %% [markdown]
# <a href="https://colab.research.google.com/github/Codeventure-team6/Proyek-codeventure/blob/yesi/Normalisasi_dan_membersihkan_data_fruit_sales_branch_jogja.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_main = pd.read_csv('/content/drive/MyDrive/Fruit Sales Data Branch Jogja.csv')
data
# Out:
#   Fruit_Name  Weight_in_Kg  Total_Cost Purchased
# 0     Durian            40     79000.0       Yes
# 1      Melon            10     83000.0       Yes
# 2      Apple            47     67000.0       Yes
# 3     Orange            70     63000.0        No
# 4      Melon            59         NaN       Yes
# 5     Durian            40     76000.0       Yes
# 6      Melon            20     34000.0        No
# 7    Avocado            21     38500.0       Yes
# 8      Apple            24     38000.0       Yes

# %%
df_jogja = pd.read_csv('/content/drive/MyDrive/Fruit Sales Data.csv')
data
# Out:
#   Fruit_Name  Weight_in_Kg  Total_Cost Purchased
# 0     Durian            40     79000.0       Yes
# 1      Melon            10     83000.0       Yes
# 2      Apple            47     67000.0       Yes
# 3     Orange            70     63000.0        No
# 4      Melon            59         NaN       Yes
# 5     Durian            40     76000.0       Yes
# 6      Melon            20     34000.0        No
# 7    Avocado            21     38500.0       Yes
# 8      Apple            24     38000.0       Yes

# %%
df_combined = pd.concat([df_main, df_jogja], ignore_index=True)

# %%
df_combined['Fruit_Name'] = df_combined['Fruit_Name'].str.strip().str.title()
df_combined['Purchased'] = df_combined['Purchased'].str.strip().str.capitalize()

# %%
print("Nilai hilang sebelum dibersihkan:")
print(df_combined.isnull().sum())
# Out:
# Nilai hilang sebelum dibersihkan:
# Fruit_Name      0
# Weight_in_Kg    2
# Total_Cost      3
# Purchased       0
# dtype: int64

# %%
df_cleaned = df_combined.dropna()

# %%
print("\nData setelah dibersihkan:")
print(df_cleaned.head())
# Out:
# Data setelah dibersihkan:
#   Fruit_Name  Weight_in_Kg  Total_Cost Purchased
# 0     Durian          40.0     79000.0       Yes
# 1      Melon          10.0     83000.0       Yes
# 2      Apple          47.0     67000.0       Yes
# 3     Orange          70.0     63000.0        No
# 5     Durian          40.0     76000.0       Yes
